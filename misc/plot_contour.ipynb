# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
N = 100
OUT_FILE = "../out/contour.png"

# %%
# 乱数生成
x = np.random.randn(100, 2)
x[:,1] = x[:,0]+.5*x[:,1]

# 平均と共分散行列の逆行列
mu = np.mean(x, axis=0)
s2 = np.cov(x.T)
s2_inv = np.linalg.inv(s2)

# メッシュグリッド生成
x_axis = np.linspace(-3, 3, N)
y_axis = np.linspace(-3, 3, N)
X, Y = np.meshgrid(x_axis, y_axis)
Z = s2_inv[0, 0]*X**2+s2_inv[0,1]*X*Y+s2_inv[1, 1]*Y**2

# プロット 
plt.xlim(-3, 3)
plt.ylim(-3, 3)
plt.contourf(X, Y, Z, 14, alpha=.75, cmap=plt.cm.hot) # 等高線の隙間の色設定
C = plt.contour(X, Y, Z, 14, colors='k', linewidths=.5) # 等高線の設定
plt.scatter(x[:,0], x[:,1], color='w', alpha=.5) # 散布図
plt.gca().set_aspect('equal') # 正方形出力
plt.clabel(C, inline=1, fontsize=8) # 等高線の値表示
plt.show()
# plt.savefig(OUT_FILE, transparent=False, bbox_inches='tight', pad_inches=0)
