# %%
from sklearn import datasets
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import numpy as np

# %%
digits = datasets.load_digits()
X = digits.data

# %%
# クラスター数2でMNISTをkmeans
km = KMeans(n_clusters=2, random_state=0).fit(X)

# ラベル
print(km.labels_)

# クラスター中心
print(km.cluster_centers_)

# 距離二乗和の総和
print(km.inertia_)
# Out:
# [0 1 1 ... 1 1 1]
# [[0.00000000e+00 2.31316726e-02 1.94128114e+00 1.05444840e+01
#   1.10000000e+01 2.56049822e+00 2.34875445e-01 5.33807829e-02
#   3.64291930e-17 3.79003559e-01 7.75978648e+00 1.38416370e+01
#   8.77580071e+00 4.67615658e+00 7.75800712e-01 1.17437722e-01
#   3.55871886e-03 1.80960854e+00 1.23932384e+01 8.72241993e+00
#   2.54982206e+00 5.67971530e+00 2.40925267e+00 1.19217082e-01
#   3.55871886e-03 4.13701068e+00 1.36637011e+01 5.59964413e+00
#   3.83096085e+00 7.03024911e+00 4.04626335e+00 7.11743772e-03
#   0.00000000e+00 5.97864769e+00 1.37864769e+01 8.10676157e+00
#   8.46441281e+00 1.09323843e+01 4.93060498e+00 0.00000000e+00
#   2.84697509e-02 3.78647687e+00 1.29234875e+01 8.23665480e+00
#   7.19572954e+00 1.06387900e+01 5.41103203e+00 7.47330961e-02
#   1.77935943e-02 6.61921708e-01 8.54804270e+00 1.00088968e+01
#   9.84341637e+00 9.57651246e+00 4.33985765e+00 2.11743772e-01
#   7.58941521e-19 2.31316726e-02 2.07117438e+00 1.08007117e+01
#   1.34857651e+01 6.75444840e+00 1.57473310e+00 5.69395018e-02]
#  [0.00000000e+00 4.31578947e-01 6.68987854e+00 1.24234818e+01
#   1.22340081e+01 7.24777328e+00 1.87530364e+00 1.64372470e-01
#   8.09716599e-03 2.72874494e+00 1.15757085e+01 1.11319838e+01
#   1.09635628e+01 9.76842105e+00 2.33360324e+00 1.03643725e-01
#   2.42914980e-03 2.96194332e+00 8.77004049e+00 6.20566802e+00
#   9.16761134e+00 8.77408907e+00 1.50607287e+00 1.86234818e-02
#   1.32272665e-17 1.71093117e+00 7.01052632e+00 1.02874494e+01
#   1.27012146e+01 7.78866397e+00 1.53117409e+00 2.64545330e-17
#   0.00000000e+00 6.83400810e-01 4.88259109e+00 9.51093117e+00
#   1.11376518e+01 7.74817814e+00 1.98947368e+00 0.00000000e+00
#   1.05818132e-16 5.81376518e-01 4.13198381e+00 6.76923077e+00
#   7.88906883e+00 7.14331984e+00 2.56680162e+00 5.66801619e-03
#   2.42914980e-03 7.23886640e-01 7.03319838e+00 9.32550607e+00
#   9.22186235e+00 8.38623482e+00 3.44534413e+00 2.04048583e-01
#   8.09716599e-04 3.95951417e-01 7.14412955e+00 1.26753036e+01
#   1.10461538e+01 6.76842105e+00 2.29230769e+00 5.04453441e-01]]
# 1914619.617550103

# %%
# エルボー法
k_max = 20
dist = []
for i in range(1, k_max):
    km = km = KMeans(n_clusters=i, random_state=0).fit(X)
    dist.append(km.inertia_)

# プロット
plt.plot(range(1, k_max), dist, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show()
